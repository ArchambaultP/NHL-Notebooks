# %%
from ift6758.data import load_entire_dataset

# %%
load_entire_dataset()

# %%
from ift6758.data import import_dataset
import pandas as pd

# %%
json_data = import_dataset(2016, "P", returnData=True)
print(type(json_data[0]))
pd.DataFrame(json_data[0])
# Out:
# <class 'dict'>
#                                                    copyright      gamePk  \
# wait       NHL and the NHL Shield are registered trademar...  2016030111
# timeStamp  NHL and the NHL Shield are registered trademar...  2016030111
# game       NHL and the NHL Shield are registered trademar...  2016030111
# datetime   NHL and the NHL Shield are registered trademar...  2016030111
# status     NHL and the NHL Shield are registered trademar...  2016030111
# teams      NHL and the NHL Shield are registered trademar...  2016030111
# players    NHL and the NHL Shield are registered trademar...  2016030111
# venue      NHL and the NHL Shield are registered trademar...  2016030111
# plays      NHL and the NHL Shield are registered trademar...  2016030111
# linescore  NHL and the NHL Shield are registered trademar...  2016030111
# boxscore   NHL and the NHL Shield are registered trademar...  2016030111
# decisions  NHL and the NHL Shield are registered trademar...  2016030111
#
#                                         link         metaData  \
# wait       /api/v1/game/2016030111/feed/live               10
# timeStamp  /api/v1/game/2016030111/feed/live  20170920_092508
# game       /api/v1/game/2016030111/feed/live              NaN
# datetime   /api/v1/game/2016030111/feed/live              NaN
# status     /api/v1/game/2016030111/feed/live              NaN
# teams      /api/v1/game/2016030111/feed/live              NaN
# players    /api/v1/game/2016030111/feed/live              NaN
# venue      /api/v1/game/2016030111/feed/live              NaN
# plays      /api/v1/game/2016030111/feed/live              NaN
# linescore  /api/v1/game/2016030111/feed/live              NaN
# boxscore   /api/v1/game/2016030111/feed/live              NaN
# decisions  /api/v1/game/2016030111/feed/live              NaN
#
#                                                     gameData  \
# wait                                                     NaN
# timeStamp                                                NaN
# game       {'pk': 2016030111, 'season': '20162017', 'type...
# datetime   {'dateTime': '2017-04-12T23:00:00Z', 'endDateT...
# status     {'abstractGameState': 'Final', 'codedGameState...
# teams      {'away': {'id': 3, 'name': 'New York Rangers',...
# players    {'ID8471958': {'id': 8471958, 'fullName': 'Dan...
# venue      {'name': 'Centre Bell', 'link': '/api/v1/venue...
# plays                                                    NaN
# linescore                                                NaN
# boxscore                                                 NaN
# decisions                                                NaN
#
#                                                     liveData
# wait                                                     NaN
# timeStamp                                                NaN
# game                                                     NaN
# datetime                                                 NaN
# status                                                   NaN
# teams                                                    NaN
# players                                                  NaN
# venue                                                    NaN
# plays      {'allPlays': [{'result': {'event': 'Game Sched...
# linescore  {'currentPeriod': 3, 'currentPeriodOrdinal': '...
# boxscore   {'teams': {'away': {'team': {'id': 3, 'name': ...
# decisions  {'winner': {'id': 8468685, 'fullName': 'Henrik...
